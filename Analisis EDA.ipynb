# %% [markdown]
# Analisis Exploratorio de Datos
#
# Introducción
#
# Qué es un EDA
# -Comprender mejor un conjunto de datos:
# -Identificar patrones, detectar anomalías, verificar suposiciones y resumir sus principales características
#
# Para este proyecto utilizaremos el DATESET IRIS
#
# Es un conjunto de datos. cláciso multicase usado para tareas de clasificación
#
# contiene  150 muestras de tres especies de flores, con cuatro características
#
# 1.-Longitud de sépalos
# 2.-Anchura de sépalos
# 3.-Longitud de pétalos
# 4.-Anchura de pétalos
#
# Objetivo Principal de un Análisis exploratorio de datos comprender y explorar los datos, antes de aplicar modelos

# %% [markdown]
# ### Inicializacion

# %%
#Inicializacción 
#importamos librerias necesarias
# !pip install seaborn
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 25.2
# [notice] To update, run: C:\Users\esmer\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Ajustes Iniciales

# %%
# %matplotlib inline #Se utiliza para que las vizualizacione sean en el mismo notebook

plt.style.use("bmh")
sns.set(style="whitegrid")
# Out:
# UsageError: unrecognized arguments: #Se utiliza para que las vizualizacione sean en el mismo notebook

# %% [markdown]
# ## Cargar y preprocesamiento del dataset

# %% [markdown]
# ### Lectura de datos

# %%
df = pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ### Reenombrar Variables

# %%
df.rename({'SepalLengthCm':'Sep_len',
           'SepalWidthCm': 'Sep_width',
           'PetalLengthCm': 'Petal_len',
           'PetalWidthCm':'Petal_width',
          'Species': 'Especie'},
         axis=1, inplace=True)
df
# Out:
#       Id  Sep_len  Sep_width  Petal_len  Petal_width         Especie
# 0      1      5.1        3.5        1.4          0.2     Iris-setosa
# 1      2      4.9        3.0        1.4          0.2     Iris-setosa
# 2      3      4.7        3.2        1.3          0.2     Iris-setosa
# 3      4      4.6        3.1        1.5          0.2     Iris-setosa
# 4      5      5.0        3.6        1.4          0.2     Iris-setosa
# ..   ...      ...        ...        ...          ...             ...
# 145  146      6.7        3.0        5.2          2.3  Iris-virginica
# 146  147      6.3        2.5        5.0          1.9  Iris-virginica
# 147  148      6.5        3.0        5.2          2.0  Iris-virginica
# 148  149      6.2        3.4        5.4          2.3  Iris-virginica
# 149  150      5.9        3.0        5.1          1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Limpieza de datos
#
# En este paso eliminamos la columna id con drop

# %%
df.drop('Id', axis=1 ,inplace = True)

# %% [markdown]
# ## Analisis descriptivo

# %% [markdown]
# Dimensiones del dataset

# %%
df.shape #Podemos ver 150 filas por 5 columnas
# Out:
# (150, 5)

# %% [markdown]
# ### Informacion general del data set

# %%
df.info() # Se utiliza para ver los tipos de datos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sep_len      150 non-null    float64
#  1   Sep_width    150 non-null    float64
#  2   Petal_len    150 non-null    float64
#  3   Petal_width  150 non-null    float64
#  4   Especie      150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe() # Nos ayuda a ver los datos estadisticos comunes
# Out:
#           Sep_len   Sep_width   Petal_len  Petal_width
# count  150.000000  150.000000  150.000000   150.000000
# mean     5.843333    3.054000    3.758667     1.198667
# std      0.828066    0.433594    1.764420     0.763161
# min      4.300000    2.000000    1.000000     0.100000
# 25%      5.100000    2.800000    1.600000     0.300000
# 50%      5.800000    3.000000    4.350000     1.300000
# 75%      6.400000    3.300000    5.100000     1.800000
# max      7.900000    4.400000    6.900000     2.500000

# %%
df['Especie'].value_counts() # Contamos las muestras por especie
# Out:
# Especie
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='Especie', palette = 'pastel')
# Out:
# C:\Users\esmer\AppData\Local\Temp\ipykernel_13972\3783471867.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Especie', palette = 'pastel')
# <Axes: xlabel='Especie', ylabel='count'>

# %%
#para mejorar la informacion es importante las etiquetas
plt.figure(figsize=(8,6))
sns.countplot(data=df, x='Especie', palette = 'pastel')
plt.ylabel('Numero de muestras')#la eiqueta que esta cuantificando
plt.title('Numero de muestras por especie')
plt.xticks(rotation = 45)
plt.show
# Out:
# C:\Users\esmer\AppData\Local\Temp\ipykernel_13972\1749661637.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Especie', palette = 'pastel')
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Comprobar de las variables nulas

# %%
df.isnull().sum()# nos ayuda a detectar valores nulos
# Out:
# Sep_len        0
# Sep_width      0
# Petal_len      0
# Petal_width    0
# Especie        0
# dtype: int64

# %% [markdown]
# ## Analisis univariado

# %% [markdown]
# Longitud del sepalo

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
sns.histplot(df['Sep_len'], kde=True, bins=20, color='purple')
plt.title('Histograma con KDE - Longitud del sépalo')
plt.xlabel('Longitud del sépalo (cm)')
plt.ylabel('Frecuencia')

# 2. Boxplot
plt.subplot(1, 3, 2)
sns.boxplot(y=df['Sep_len'], color='lightgreen')
plt.title('Boxplot - Longitud del sépalo')
plt.xlabel('Longitud del sépalo (cm)')
plt.ylabel('')

# 3. Violin plot
plt.subplot(1, 3, 3)
sns.violinplot(y=df['Sep_len'], color='lightblue')
plt.title('Violin plot - Longitud del sépalo')
plt.xlabel('Longitud del sépalo (cm)')
plt.ylabel('')

# Mostrar los gráficos
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
sns.histplot(df['Sep_width'], kde=True, bins=20, color='purple')
plt.title('Histograma con KDE - Ancho del sépalo')
plt.xlabel('Longitud del sépalo (cm)')
plt.ylabel('Frecuencia')

# 2. Boxplot
plt.subplot(1, 3, 2)
sns.boxplot(y=df['Sep_width'], color='lightgreen')
plt.title('Boxplot - Ancho del sépalo')
plt.xlabel('Longitud del sépalo (cm)')
plt.ylabel('')

# 3. Violin plot
plt.subplot(1, 3, 3)
sns.violinplot(y=df['Sep_width'], color='lightblue')
plt.title('Violin plot - Ancho del sépalo')
plt.xlabel('Longitud del sépalo (cm)')
plt.ylabel('')

# Mostrar los gráficos
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analisis multivariable

# %%
# Crear una figura con una cuadrícula de 2x2 subgráficos
fig, axs = plt.subplots(2, 2, figsize=(14, 12))

# 1. Histograma de Longitud del Sépalo por Especie
sns.histplot(data=df, x='Sep_len', hue='Especie', multiple='stack', palette='Set1', bins=20, ax=axs[0, 0])
axs[0, 0].set_title('Histograma de Longitud del Sépalo por Especie')
axs[0, 0].set_xlabel('Longitud del Sépalo (cm)')
axs[0, 0].set_ylabel('Frecuencia')

# 2. Diagrama de Caja (Boxplot) de Longitud del Sépalo por Especie
sns.boxplot(data=df, x='Especie', y='Sep_len', palette='Set1', ax=axs[0, 1])
axs[0, 1].set_title('Diagrama de Caja de Longitud del Sépalo por Especie')
axs[0, 1].set_xlabel('Especie')
axs[0, 1].set_ylabel('Longitud del Sépalo (cm)')

# 3. Gráfico de Violín de Longitud del Sépalo por Especie
sns.violinplot(data=df, x='Especie', y='Sep_len', palette='Set1', ax=axs[1, 0])
axs[1, 0].set_title('Gráfico de Violín de Longitud del Sépalo por Especie')
axs[1, 0].set_xlabel('Especie')
axs[1, 0].set_ylabel('Longitud del Sépalo (cm)')

# 4. Gráfico de Dispersión (Scatter Plot) de Longitud del Sépalo por Especie
sns.scatterplot(data=df, x='Sep_len', y='Petal_len', hue='Especie', palette='Set1', style='Especie', ax=axs[1, 1])
axs[1, 1].set_title('Gráfico de Dispersión de Longitud del Sépalo y Longitud del Pétalo por Especie')
axs[1, 1].set_xlabel('Longitud del Sépalo (cm)')
axs[1, 1].set_ylabel('Longitud del Pétalo (cm)')
axs[1, 1].legend(title='Especie')

# Ajustar el espacio entre subgráficos
plt.tight_layout()
plt.show()
# Out:
# C:\Users\esmer\AppData\Local\Temp\ipykernel_13972\2848868018.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Especie', y='Sep_len', palette='Set1', ax=axs[0, 1])
# C:\Users\esmer\AppData\Local\Temp\ipykernel_13972\2848868018.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Especie', y='Sep_len', palette='Set1', ax=axs[1, 0])

# %% [markdown]
# Haciendo el analisis multivariado podemos entener mejor los datos podemos notar que dependiendo de la longitud puede ser una especie

# %% [markdown]
# ## Relacion entre variables

# %%
sns.pairplot(df, hue='Especie', markers=["o","s","D"], palette="pastel")
plt.suptitle('Pairplot de las variables Iris', y=1.02)
plt.show()

# %% [markdown]
# Este tipo de graficos nos ayuda a analizar entre variables sus diferencias

# %% [markdown]
# ## Correlacion entre variables

# %%
df.corr(numeric_only=True,)
# Out:
#               Sep_len  Sep_width  Petal_len  Petal_width
# Sep_len      1.000000  -0.109369   0.871754     0.817954
# Sep_width   -0.109369   1.000000  -0.420516    -0.356544
# Petal_len    0.871754  -0.420516   1.000000     0.962757
# Petal_width  0.817954  -0.356544   0.962757     1.000000

# %%
plt.figure(figsize=(8, 6))
correlation_matrix = df.corr(numeric_only=True)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Mapa de calor de correlación entre variables')
plt.show()

# %% [markdown]
# ## Conclusiones

# %%
Este dataset en un conjunto de datos bastante balanceado podemos ver que es facil de entender y podemos ver como la especie va dependiendo de la longitud sel sepalo asi co
